# %% [markdown]
# # **Capítulo 7: Convergencia y ajuste de modelos**
#
# ## Clasificación de imágenes usando la base de datos CIFAR10

# %% [markdown]
# Carga y preprocesado de datos

# %%
from tensorflow.keras.datasets import cifar10

# Cargamos los datos
(X_train, Y_train), (X_test, Y_test) = cifar10.load_data()

# Normalizamos las imágenes
X_train = X_train.astype('float32') / 255
X_test = X_test.astype('float32') / 255

# %% [markdown]
# Visualización del aspecto de los datos

# %%
import matplotlib.pyplot as plt

# Dimensiones de los conjuntos de datos
print(f'Tamaño del conjunto de entrenamiento: {len(X_train)}')
print(f'Tamaño del conjunto de test: {len(X_test)}')

# Obtenemos un lote o batch de imágenes de entrenamiento
imagenes, etiquetas = X_train[:2], Y_train[:2]
print(f'Tamaño de las imágenes: {imagenes.shape[1:]}')

# Diccionario de etiquetas
clases = {0: 'avión', 1: 'coche', 2: 'pájaro', 3: 'gato', 4: 'ciervo',\
          5: 'perro', 6: 'rana', 7: 'caballo', 8: 'barco', 9: 'camión'}

# Visualizamos las imágenes y etiquetas de un batch de entrenamiento
fig, axs = plt.subplots(1, 2, figsize=(10, 10))
for i in range(2):
    axs[i].imshow(imagenes[i])
    axs[i].set_title(f'Etiqueta: {clases[etiquetas[i].item()]}')
    axs[i].axis('off')
plt.show()
# Out:
# Tamaño del conjunto de entrenamiento: 50000
# Tamaño del conjunto de test: 10000
# Tamaño de las imágenes: (32, 32, 3)

# %% [markdown]
# Definición y visualización de los aumentos empleados en el caso avanzado

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import RandomFlip, RandomRotation,\
    RandomBrightness

# Modelo de aumentos de datos
aumentos = Sequential()
aumentos.add(RandomRotation(0.01, fill_mode='nearest',
                                  input_shape=(32, 32, 3)))
aumentos.add(RandomFlip('horizontal'))
aumentos.add(RandomBrightness(0.2, value_range=(0, 1)))

# Visualizamos las imágenes aumentadas de un batch de entrenamiento
imagenes_aug = aumentos(imagenes)
fig, axs = plt.subplots(1, 2, figsize=(10, 10))
for i in range(2):
    axs[i].imshow(imagenes_aug[i])
    axs[i].axis('off')
plt.show()

# %% [markdown]
# Creación de la CNN a usar

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization

def crear_CNN(usar_aumentos=False, normalizacion=False, dropout=0):
    entrada = Input(shape=(32, 32, 3))

    # Aumento de datos
    if usar_aumentos:
        x = aumentos(entrada)
    else:
        x = entrada

    # 1) Bloque extractor de características
    # - Convolución con activación -> Normalización -> Pooling
    x = Conv2D(16, kernel_size=5, padding='same', activation='relu')(x)
    if normalizacion:
        x = BatchNormalization()(x)
    x = MaxPooling2D(pool_size=2)(x)
    # - Convolución con activación -> Normalización -> Pooling
    x = Conv2D(32, kernel_size=5, padding='same', activation='relu')(x)
    if normalizacion:
        x = BatchNormalization()(x)
    x = MaxPooling2D(pool_size=2)(x)
    # - Dropout
    x = Dropout(dropout)(x)

    # 2) Bloque clasificador de características
    x = Flatten()(x)
    x = Dense(256, activation='relu')(x)
    x = Dense(128, activation='relu')(x)
    salida = Dense(10, activation='softmax')(x)

    return Model(inputs=entrada, outputs=salida)

# %% [markdown]
# Entrenamiento del caso base

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

# Caso base
modelo_base = crear_CNN()
modelo_base.compile(optimizer='adam',
                    loss='sparse_categorical_crossentropy',
                    metrics=['accuracy'])

# Model checkpoint
checkpoint = ModelCheckpoint(filepath='modelo_base.h5',
                             monitor='val_accuracy',
                             save_best_only=True,
                             save_weights_only=True,
                             verbose=1)

# Entrenamos el modelo base
historia_base = modelo_base.fit(X_train, Y_train, 
                                validation_split=0.2,
                                epochs=50, 
                                batch_size=256,
                                callbacks=[checkpoint])
# Out:
# Epoch 1/50
# 157/157 [==============================] - ETA: 0s - loss: 1.6601 - accuracy: 0.3936
# Epoch 1: val_accuracy improved from -inf to 0.47700, saving model to modelo_base.h5
# 157/157 [==============================] - 5s 32ms/step - loss: 1.6601 - accuracy: 0.3936 - val_loss: 1.4363 - val_accuracy: 0.4770
# Epoch 2/50
# 156/157 [============================>.] - ETA: 0s - loss: 1.3280 - accuracy: 0.5197
# Epoch 2: val_accuracy improved from 0.47700 to 0.53280, saving model to modelo_base.h5
# 157/157 [==============================] - 4s 28ms/step - loss: 1.3281 - accuracy: 0.5197 - val_loss: 1.2899 - val_accuracy: 0.5328
# Epoch 3/50
# 156/157 [============================>.] - ETA: 0s - loss: 1.1638 - accuracy: 0.5858
# Epoch 3: val_accuracy improved from 0.53280 to 0.57880, saving model to modelo_base.h5
# 157/157 [==============================] - 5s 29ms/step - loss: 1.1637 - accuracy: 0.5858 - val_loss: 1.1882 - val_accuracy: 0.5788
# Epoch 4/50
# 156/157 [============================>.] - ETA: 0s - loss: 1.0640 - accuracy: 0.6239
# Epoch 4: val_accuracy improved from 0.57880 to 0.61230, saving model to modelo_base.h5
# 157/157 [==============================] - 5s 32ms/step - loss: 1.0638 - accuracy: 0.6239 - val_loss: 1.0916 - val_accuracy: 0.6123
# Epoch 5/50
# 156/157 [============================>.] - ETA: 0s - loss: 0.9849 - accuracy: 0.6518
# Epoch 5: val_accuracy improved from 0.61230 to 0.63150, saving model to modelo_base.h5
# 157/157 [==============================] - 5s 31ms/step - loss: 0.9849 - accuracy: 0.6518 - val_loss: 1.0311 - val_accuracy: 0.6315
# Epoch 6/50
# 156/157 [============================>.] - ETA: 0s - loss: 0.9211 - accuracy: 0.6770
# Epoch 6: val_accuracy improved from 0.63150 to 0.65520, saving model to modelo_base.h5
# 157/157 [==============================] - 5s 32ms/step - loss: 0.9213 - accuracy: 0.6768 - val_loss: 0.9943 - val_accuracy: 0.6552
# Epoch 7/50
# 155/157 [============================>.] - ETA: 0s - loss: 0.8636 - accuracy: 0.6964
# Epoch 7: val_accuracy improved from 0.65520 to 0.65960, saving model to modelo_base.h5
# 157/157 [==============================] - 5s 31ms/step - loss: 0.8635 - accuracy: 0.6965 - val_loss: 0.9787 - val_accuracy: 0.6596
# Epoch 8/50
# 155/157 [============================>.] - ETA: 0s - loss: 0.8059 - accuracy: 0.7180
# Epoch 8: val_accuracy improved from 0.65960 to 0.65970, saving model to modelo_base.h5
# 157/157 [==============================] - 5s 32ms/step - loss: 0.8052 - accuracy: 0.7182 - val_loss: 1.0085 - val_accuracy: 0.6597
# Epoch 9/50
# 156/157 [============================>.] - ETA: 0s - loss: 0.7466 - accuracy: 0.7388
# Epoch 9: val_accuracy improved from 0.65970 to 0.67140, saving model to modelo_base.h5
# 157/157 [==============================] - 5s 32ms/step - loss: 0.7466 - accuracy: 0.7388 - val_loss: 0.9475 - val_accuracy: 0.6714
# Epoch 10/50
# 156/157 [============================>.] - ETA: 0s - loss: 0.6962 - accuracy: 0.7564
# Epoch 10: val_accuracy improved from 0.67140 to 0.67770, saving model to modelo_base.h5
# 157/157 [==============================] - 5s 32ms/step - loss: 0.6961 - accuracy: 0.7563 - val_loss: 0.9462 - val_accuracy: 0.6777
# Epoch 11/50
# 156/157 [============================>.] - ETA: 0s - loss: 0.6446 - accuracy: 0.7739
# Epoch 11: val_accuracy did not improve from 0.67770
# 157/157 [==============================] - 6s 35ms/step - loss: 0.6448 - accuracy: 0.7737 - val_loss: 0.9994 - val_accuracy: 0.6644
# Epoch 12/50
# 155/157 [============================>.] - ETA: 0s - loss: 0.6042 - accuracy: 0.7894
# Epoch 12: val_accuracy improved from 0.67770 to 0.68420, saving model to modelo_base.h5
# 157/157 [==============================] - 5s 31ms/step - loss: 0.6046 - accuracy: 0.7892 - val_loss: 0.9579 - val_accuracy: 0.6842
# Epoch 13/50
# 155/157 [============================>.] - ETA: 0s - loss: 0.5349 - accuracy: 0.8142
# Epoch 13: val_accuracy did not improve from 0.68420
# 157/157 [==============================] - 5s 35ms/step - loss: 0.5348 - accuracy: 0.8140 - val_loss: 0.9677 - val_accuracy: 0.6790
# Epoch 14/50
# 157/157 [==============================] - ETA: 0s - loss: 0.4858 - accuracy: 0.8306
# Epoch 14: val_accuracy did not improve from 0.68420
# 157/157 [==============================] - 6s 40ms/step - loss: 0.4858 - accuracy: 0.8306 - val_loss: 1.0047 - val_accuracy: 0.6836
# Epoch 15/50
# 156/157 [============================>.] - ETA: 0s - loss: 0.4290 - accuracy: 0.8528
# Epoch 15: val_accuracy improved from 0.68420 to 0.69290, saving model to modelo_base.h5
# 157/157 [==============================] - 6s 37ms/step - loss: 0.4291 - accuracy: 0.8528 - val_loss: 1.0151 - val_accuracy: 0.6929
# Epoch 16/50
# 155/157 [============================>.] - ETA: 0s - loss: 0.3896 - accuracy: 0.8654
# Epoch 16: val_accuracy did not improve from 0.69290
# 157/157 [==============================] - 6s 37ms/step - loss: 0.3900 - accuracy: 0.8652 - val_loss: 1.1353 - val_accuracy: 0.6703
# Epoch 17/50
# 157/157 [==============================] - ETA: 0s - loss: 0.3400 - accuracy: 0.8841
# Epoch 17: val_accuracy did not improve from 0.69290
# 157/157 [==============================] - 6s 38ms/step - loss: 0.3400 - accuracy: 0.8841 - val_loss: 1.1394 - val_accuracy: 0.6815
# Epoch 18/50
# 155/157 [============================>.] - ETA: 0s - loss: 0.2936 - accuracy: 0.9007
# Epoch 18: val_accuracy did not improve from 0.69290
# 157/157 [==============================] -
val_accuracy did not improve from 0.69290
# 157/157 [==============================] - 6s 36ms/step - loss: 0.0484 - accuracy: 0.9830 - val_loss: 2.7774 - val_accuracy: 0.6698
# Epoch 44/50
# 156/157 [============================>.] - ETA: 0s - loss: 0.0378 - accuracy: 0.9871
# Epoch 44: val_accuracy did not improve from 0.69290
# 157/157 [==============================] - 6s 36ms/step - loss: 0.0378 - accuracy: 0.9872 - val_loss: 2.9681 - val_accuracy: 0.6622
# Epoch 45/50
# 155/157 [============================>.] - ETA: 0s - loss: 0.0387 - accuracy: 0.9873
# Epoch 45: val_accuracy did not improve from 0.69290
# 157/157 [==============================] - 6s 36ms/step - loss: 0.0389 - accuracy: 0.9872 - val_loss: 2.7965 - val_accuracy: 0.6687
# Epoch 46/50
# 157/157 [==============================] - ETA: 0s - loss: 0.0476 - accuracy: 0.9836
# Epoch 46: val_accuracy did not improve from 0.69290
# 157/157 [==============================] - 6s 36ms/step - loss: 0.0476 - accuracy: 0.9836 - val_loss: 2.8873 - val_accuracy: 0.6668
# Epoch 47/50
# 155/157 [============================>.] - ETA: 0s - loss: 0.0560 - accuracy: 0.9802
# Epoch 47: val_accuracy did not improve from 0.69290
# 157/157 [==============================] - 5s 35ms/step - loss: 0.0560 - accuracy: 0.9803 - val_loss: 2.7790 - val_accuracy: 0.6689
# Epoch 48/50
# 155/157 [============================>.] - ETA: 0s - loss: 0.0519 - accuracy: 0.9816
# Epoch 48: val_accuracy did not improve from 0.69290
# 157/157 [==============================] - 6s 36ms/step - loss: 0.0521 - accuracy: 0.9815 - val_loss: 2.8591 - val_accuracy: 0.6698
# Epoch 49/50
# 155/157 [============================>.] - ETA: 0s - loss: 0.0396 - accuracy: 0.9871
# Epoch 49: val_accuracy did not improve from 0.69290
# 157/157 [==============================] - 6s 36ms/step - loss: 0.0403 - accuracy: 0.9869 - val_loss: 2.8942 - val_accuracy: 0.6643
# Epoch 50/50
# 157/157 [==============================] - ETA: 0s - loss: 0.0499 - accuracy: 0.9823
# Epoch 50: val_accuracy did not improve from 0.69290
# 157/157 [==============================] - 6s 36ms/step - loss: 0.0499 - accuracy: 0.9823 - val_loss: 2.9041 - val_accuracy: 0.6715

# %% [markdown]
# Entrenamiento del caso avanzado

# %%
from tensorflow.keras.callbacks import EarlyStopping

# Caso avanzado
modelo_avan = crear_CNN(usar_aumentos=True, normalizacion=True,
                        dropout=0.5)
modelo_avan.compile(optimizer='adam',
                    loss='sparse_categorical_crossentropy',
                    metrics=['accuracy'])

# Model checkpoint
checkpoint = ModelCheckpoint(filepath='modelo_avan.h5',
                             monitor='val_accuracy',
                             save_best_only=True,
                             save_weights_only=True,
                             verbose=1)

# Early stopping
early_stop = EarlyStopping(monitor='val_accuracy', patience=5, verbose=1)

# Entrenamos el modelo avanzado
historia_avan = modelo_avan.fit(X_train, Y_train,
                                validation_split=0.2,
                                epochs=50,
                                batch_size=256,
                                callbacks=[checkpoint, early_stop])
# Out:
# Epoch 1/50
# 157/157 [==============================] - ETA: 0s - loss: 1.7358 - accuracy: 0.3844
# Epoch 1: val_accuracy improved from -inf to 0.19070, saving model to modelo_avan.h5
# 157/157 [==============================] - 9s 53ms/step - loss: 1.7358 - accuracy: 0.3844 - val_loss: 2.5107 - val_accuracy: 0.1907
# Epoch 2/50
# 156/157 [============================>.] - ETA: 0s - loss: 1.3644 - accuracy: 0.5096
# Epoch 2: val_accuracy improved from 0.19070 to 0.29110, saving model to modelo_avan.h5
# 157/157 [==============================] - 8s 52ms/step - loss: 1.3641 - accuracy: 0.5096 - val_loss: 2.2338 - val_accuracy: 0.2911
# Epoch 3/50
# 156/157 [============================>.] - ETA: 0s - loss: 1.2299 - accuracy: 0.5607
# Epoch 3: val_accuracy improved from 0.29110 to 0.52830, saving model to modelo_avan.h5
# 157/157 [==============================] - 8s 52ms/step - loss: 1.2297 - accuracy: 0.5606 - val_loss: 1.3571 - val_accuracy: 0.5283
# Epoch 4/50
# 157/157 [==============================] - ETA: 0s - loss: 1.1365 - accuracy: 0.5933
# Epoch 4: val_accuracy improved from 0.52830 to 0.58280, saving model to modelo_avan.h5
# 157/157 [==============================] - 8s 53ms/step - loss: 1.1365 - accuracy: 0.5933 - val_loss: 1.1927 - val_accuracy: 0.5828
# Epoch 5/50
# 156/157 [============================>.] - ETA: 0s - loss: 1.0608 - accuracy: 0.6245
# Epoch 5: val_accuracy improved from 0.58280 to 0.65250, saving model to modelo_avan.h5
# 157/157 [==============================] - 8s 53ms/step - loss: 1.0612 - accuracy: 0.6244 - val_loss: 0.9918 - val_accuracy: 0.6525
# Epoch 6/50
# 157/157 [==============================] - ETA: 0s - loss: 0.9975 - accuracy: 0.6447
# Epoch 6: val_accuracy improved from 0.65250 to 0.67760, saving model to modelo_avan.h5
# 157/157 [==============================] - 8s 52ms/step - loss: 0.9975 - accuracy: 0.6447 - val_loss: 0.9314 - val_accuracy: 0.6776
# Epoch 7/50
# 156/157 [============================>.] - ETA: 0s - loss: 0.9433 - accuracy: 0.6691
# Epoch 7: val_accuracy did not improve from 0.67760
# 157/157 [==============================] - 9s 54ms/step - loss: 0.9433 - accuracy: 0.6692 - val_loss: 1.0904 - val_accuracy: 0.6208
# Epoch 8/50
# 156/157 [============================>.] - ETA: 0s - loss: 0.8918 - accuracy: 0.6842
# Epoch 8: val_accuracy improved from 0.67760 to 0.67800, saving model to modelo_avan.h5
# 157/157 [==============================] - 8s 52ms/step - loss: 0.8923 - accuracy: 0.6840 - val_loss: 0.9264 - val_accuracy: 0.6780
# Epoch 9/50
# 156/157 [============================>.] - ETA: 0s - loss: 0.8579 - accuracy: 0.6960
# Epoch 9: val_accuracy did not improve from 0.67800
# 157/157 [==============================] - 8s 53ms/step - loss: 0.8578 - accuracy: 0.6961 - val_loss: 0.9746 - val_accuracy: 0.6693
# Epoch 10/50
# 157/157 [==============================] - ETA: 0s - loss: 0.8275 - accuracy: 0.7091
# Epoch 10: val_accuracy improved from 0.67800 to 0.70030, saving model to modelo_avan.h5
# 157/157 [==============================] - 8s 52ms/step - loss: 0.8275 - accuracy: 0.7091 - val_loss: 0.8803 - val_accuracy: 0.7003
# Epoch 11/50
# 157/157 [==============================] - ETA: 0s - loss: 0.7829 - accuracy: 0.7258
# Epoch 11: val_accuracy did not improve from 0.70030
# 157/157 [==============================] - 8s 53ms/step - loss: 0.7829 - accuracy: 0.7258 - val_loss: 0.8666 - val_accuracy: 0.6994
# Epoch 12/50
# 156/157 [============================>.] - ETA: 0s - loss: 0.7654 - accuracy: 0.7294
# Epoch 12: val_accuracy did not improve from 0.70030
# 157/157 [==============================] - 8s 52ms/step - loss: 0.7651 - accuracy: 0.7295 - val_loss: 1.0234 - val_accuracy: 0.6692
# Epoch 13/50
# 156/157 [============================>.] - ETA: 0s - loss: 0.7539 - accuracy: 0.7329
# Epoch 13: val_accuracy did not improve from 0.70030
# 157/157 [==============================] - 8s 51ms/step - loss: 0.7541 - accuracy: 0.7328 - val_loss: 0.8586 - val_accuracy: 0.6995
# Epoch 14/50
# 156/157 [============================>.] - ETA: 0s - loss: 0.7228 - accuracy: 0.7447
# Epoch 14: val_accuracy improved from 0.70030 to 0.73270, saving model to modelo_avan.h5
# 157/157 [==============================] - 8s 52ms/step - loss: 0.7232 - accuracy: 0.7445 - val_loss: 0.7739 - val_accuracy: 0.7327
# Epoch 15/50
# 157/157 [==============================] - ETA: 0s - loss: 0.6975 - accuracy: 0.7534
# Epoch 15: val_accuracy did not improve from 0.73270
# 157/157 [==============================] - 8s 53ms/step - loss: 0.6975 - accuracy: 0.7534 - val_loss: 0.9024 - val_accuracy: 0.6872
# Epoch 16/50
# 156/157 [============================>.] - ETA: 0s - loss: 0.6824 - accuracy: 0.7577
# Epoch 16: val_accuracy did not improve from 0.73270
# 157/157 [==============================] - 8s 52ms/step - loss: 0.6823 - accuracy: 0.7577 - val_loss: 0.8183 - val_accuracy: 0.7213
# Epoch 17/50
# 157/157 [==============================] - ETA: 0s - loss: 0.6613 - accuracy: 0.7656
# Epoch 17: val_accuracy improved from 0.73270 to 0.73470, saving model to modelo_avan.h5
# 157/157 [==============================] - 8s 52ms/step - loss: 0.6613 - accuracy: 0.7656 - val_loss: 0.7873 - val_accuracy: 0.7347
# Epoch 18/50
# 157/157 [==============================] - ETA: 0s - loss: 0.6485 - accuracy: 0.7693
# Epoch 18: val_accuracy did not improve from 0.73470
# 157/157 [==============================] - 8s 53ms/step - loss: 0.6485 - accuracy: 0.7693 - val_loss: 0.7713 - val_accuracy: 0.7340
# Epoch 19/50
# 157/157 [==============================] - ETA: 0s - loss: 0.6263 - accuracy: 0.7768
# Epoch 19: val_accuracy did not improve from 0.73470
# 157/157 [==============================] - 8s 51ms/step - loss: 0.6263 - accuracy: 0.7768 - val_loss: 0.8385 - val_accuracy: 0.7144
# Epoch 20/50
# 157/157 [==============================] - ETA: 0s - loss: 0.6162 - accuracy: 0.7815
# Epoch 20: val_accuracy did not improve from 0.73470
# 157/157 [==============================] - 8s 52ms/step - loss: 0.6162 - accuracy: 0.7815 - val_loss: 0.8834 - val_accuracy: 0.7074
# Epoch 21/50
# 157/157 [==============================] - ETA: 0s - loss: 0.5991 - accuracy: 0.7867
# Epoch 21: val_accuracy did not improve from 0.73470
# 157/157 [==============================] - 8s 52ms/step - loss: 0.5991 - accuracy: 0.7867 - val_loss: 0.7724 - val_accuracy: 0.7322
# Epoch 22/50
# 156/157 [============================>.] - ETA: 0s - loss: 0.5940 - accuracy: 0.7888
# Epoch 22: val_accuracy improved from 0.73470 to 0.73760, saving model to modelo_avan.h5
# 157/157 [==============================] - 9s 54ms/step - loss: 0.5940 - accuracy: 0.7888 - val_loss: 0.7757 - val_accuracy: 0.7376
# Epoch 23/50
# 156/157 [============================>.] - ETA: 0s - loss: 0.5742 - accuracy: 0.7966
# Epoch 23: val_accuracy improved from 0.73760 to 0.74110, saving model to modelo_avan.h5
# 157/157 [==============================] - 8s 53ms/step - loss: 0.5746 - accuracy: 0.7965 - val_loss: 0.7839 - val_accuracy: 0.7411
# Epoch 24/50
# 157/157 [==============================] - ETA: 0s - loss: 0.5605 - accuracy: 0.8016
# Epoch 24: val_accuracy improved from 0.74110 to 0.74120, saving model to modelo_avan.h5
# 157/157 [==============================] - 8s 53ms/step - loss: 0.5605 - accuracy: 0.8016 - val_loss: 0.7662 - val_accuracy: 0.7412
# Epoch 25/50
# 156/157 [============================>.] - ETA: 0s - loss: 0.5538 - accuracy: 0.8048
# Epoch 25: val_accuracy improved from 0.74120 to 0.74730, saving model to modelo_avan.h5
# 157/157 [==============================] - 8s 54ms/step - loss: 0.5540 - accuracy: 0.8047 - val_loss: 0.7713 - val_accuracy: 0.7473
# Epoch 26/50
# 157/157 [==============================] - ETA: 0s - loss: 0.5380 - accuracy: 0.8082
# Epoch 26: val_accuracy did not improve from 0.74730
# 157/157 [==============================] - 8s 53ms/step - loss: 0.5380 - accuracy: 0.8082 - val_loss: 0.8140 - val_accuracy: 0.7402
# Epoch 27/50
# 157/157 [==============================] - ETA: 0s - loss: 0.5324 - accuracy: 0.8114
# Epoch 27: val_accuracy did not improve from 0.74730
# 157/157 [==============================] - 8s 52ms/step - loss: 0.5324 - accuracy: 0.8114 - val_loss: 0.8331 - val_accuracy: 0.7262
# Epoch 28/50
# 156/157 [============================>.] - ETA: 0s - loss: 0.5245 - accuracy: 0.8124
# Epoch 28: val_accuracy did not improve from 0.74730
# 157/157 [==============================] - 8s 52ms/step - loss: 0.5243 - accuracy: 0.8126 - val_loss: 0.8647 - val_accuracy: 0.7190
# Epoch 29/50
# 156/157 [============================>.] - ETA: 0s - loss: 0.5142 - accuracy: 0.8171
# Epoch 29: val_accuracy did not improve from 0.74730
# 157/157 [==============================] - 8s 52ms/step - loss: 0.5141 - accuracy: 0.8172 - val_loss: 0.7706 - val_accuracy: 0.7436
# Epoch 30/50
# 156/157 [============================>.] - ETA: 0s - loss: 0.4971 - accuracy: 0.8236
# Epoch 30: val_accuracy improved from 0.74730 to 0.75040, saving model to modelo_avan.h5
# 157/157 [==============================] - 8s 53ms/step - loss: 0.4973 - accuracy: 0.8235 - val_loss: 0.7552 - val_accuracy: 0.7504
# Epoch 31/50
# 156/157 [============================>.] - ETA: 0s - loss: 0.4855 - accuracy: 0.8259
# Epoch 31: val_accuracy did not improve from 0.75040
# 157/157 [==============================] - 8s 54ms/step - loss: 0.4854 - accuracy: 0.8260 - val_loss: 0.7897 - val_accuracy: 0.7446
# Epoch 32/50
# 156/157 [============================>.] - ETA: 0s - loss: 0.4873 - accuracy: 0.8257
# Epoch 32: val_accuracy did not improve from 0.75040
# 157/157 [==============================] - 8s 52ms/step - loss: 0.4874 - accuracy: 0.8256 - val_loss: 0.7837 - val_accuracy: 0.7480
# Epoch 33/50
# 157/157 [==============================] - ETA: 0s - loss: 0.4838 - accuracy: 0.8292
# Epoch 33: val_accuracy did not improve from 0.75040
# 157/157 [==============================] - 8s 52ms/step - loss: 0.4838 - accuracy: 0.8292 - val_loss: 0.7643 - val_accuracy: 0.7490
# Epoch 34/50
# 156/157 [============================>.] - ETA: 0s - loss: 0.4633 - accuracy: 0.8365
# Epoch 34: val_accuracy did not improve from 0.75040
# 157/157 [==============================] - 8s 52ms/step - loss: 0.4634 - accuracy: 0.8365 - val_loss: 0.7746 - val_accuracy: 0.7444
# Epoch 35/50
# 156/157 [============================>.] - ETA: 0s - loss: 0.4611 - accuracy: 0.8377
# Epoch 35: val_accuracy did not improve from 0.75040
# 157/157 [==============================] - 8s 52ms/step - loss: 0.4610 - accuracy: 0.8377 - val_loss: 0.7900 - val_accuracy: 0.7452
# Epoch 35: early stopping

# %% [markdown]
# Comparación entre el caso base y el caso avanzado

# %%
# Calcular la exactitud de test en función de la mejor exactitud de validación
# 1) Cargamos el mejor modelo
modelo_base.load_weights('modelo_base.h5')
modelo_avan.load_weights('modelo_avan.h5')
# 2) Evaluamos el modelo
test_base = modelo_base.evaluate(X_test, Y_test, verbose=0)
test_avan = modelo_avan.evaluate(X_test, Y_test, verbose=0)
print(f'Exactitud de test del modelo base: {test_base[-1]*100:.2f}%')
print(f'Exactitud de test del modelo avanzado: {test_avan[-1]*100:.2f}%')

# Visualizamos la perdida de entrenamiento y la exactitud de validación
# a lo largo de las épocas para ambos modelos
fig, axs = plt.subplots(1, 2, figsize=(15, 5))
res_comp = {'Pérdida de entrenamiento': 'loss', 'Exactitud de validación': 'val_accuracy'}
for i, (k, v) in enumerate(res_comp.items()):
    axs[i].plot(historia_base.history[v], label='Base')
    axs[i].plot(historia_avan.history[v], label='Avanzado')
    axs[i].set_xlabel('Época')
    axs[i].set_ylabel(k)
    axs[i].legend()
plt.show()
# Out:
# Exactitud de test del modelo base: 68.19%
# Exactitud de test del modelo avanzado: 74.65%

# %% [markdown]
# Cálculo de la época de paso del modelo avanzado

# %%
import numpy as np

dif_epoca = np.argmax(historia_avan.history['val_accuracy'] > np.max(historia_base.history['val_accuracy']))
print(dif_epoca)
# Out:
# 9
