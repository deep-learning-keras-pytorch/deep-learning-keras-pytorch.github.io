# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
def exponential_scheduler(epoch):
  return 0.95 ** epoch

base_lr = 0.1
epochs = np.arange(50)
lr = np.array([base_lr * exponential_scheduler(epoch) for epoch in epochs])

plt.plot(epochs, lr)
